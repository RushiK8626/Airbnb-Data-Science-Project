# %% [markdown]
# # Exploratory Data Analysis (EDA) - Merged Listings Dataset
#
# This notebook explores the uncleaned merged dataset at `data/processed/main/merged.csv`.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)
RANDOM_STATE = 42

# %%
candidate_paths = [
    Path('data/processed/main/merged.csv'),
    Path('../data/processed/main/merged.csv'),
    Path.cwd() / 'data/processed/main/merged.csv',
]

csv_path = None
for p in candidate_paths:
    if p.exists():
        csv_path = p
        break

if csv_path is None:
    raise FileNotFoundError('Could not locate merged.csv in expected locations.')

df = pd.read_csv(csv_path)
print(f'Loaded: {csv_path.resolve()}')
print(f'Shape: {df.shape[0]:,} rows x {df.shape[1]:,} columns')
df.head()
# Out:
# Loaded: C:\Users\RUSHIKESH\Projects\Airbnb Project\data\processed\main\merged.csv
# Shape: 47,813 rows x 65 columns
#    listing_id                                       listing_name  \
# 0   1754773.0  Centrally located in Accra with Chocolates to go!
# 1   5059526.0              NEW! Luxury Studio at Embassy Gardens
# 2   5296203.0                   Studio Apt. in the center of Osu
# 3   5385757.0       Oasis in Accra Central Osu Black Star Square
# 4   6531925.0  Oasis Garden - Researchers' Home(1 out of 6 ro...
#
#                   listing_type     room_type  \
# 0           Entire rental unit   entire_home
# 1           Entire rental unit   entire_home
# 2              Entire bungalow   entire_home
# 3  Private room in rental unit  private_room
# 4         Private room in home  private_room
#
#                                      cover_photo_url  photos_count   host_id  \
# 0  https://a0.muscache.com/im/pictures/ec7fdf2a-0...          34.0   9220860
# 1  https://a0.muscache.com/im/pictures/a1c70987-6...          14.0  26125588
# 2  https://a0.muscache.com/im/pictures/68216885/b...          10.0  27429560
# 3  https://a0.muscache.com/im/pictures/miso/Hosti...          14.0  14499704
# 4  https://a0.muscache.com/im/pictures/d3d5201d-5...          13.0  34168361
#
#        host_name cohost_ids cohost_names  superhost  latitude  longitude  \
# 0          Yaaba        NaN          NaN       True    5.5733    -0.1960
# 1           Alex        NaN          NaN      False    5.5860    -0.1673
# 2          Linda        NaN          NaN       True    5.5610    -0.1856
# 3         Kobina        NaN          NaN       True    5.5534    -0.1795
# 4  Gladys & Gidi        NaN          NaN       True    5.6235    -0.1790
#
#    guests  bedrooms  beds  baths registration  \
# 0     2.0       1.0   1.0    1.5        False
# 1     2.0       NaN   NaN    1.0        False
# 2     2.0       1.0   1.0    1.0        False
# 3     NaN       NaN   1.0    0.0        False
# 4     NaN       NaN   1.0    0.0        False
#
#                                            amenities instant_book  \
# 0  TV,Cable TV,Wifi,Air conditioning,Kitchen,Free...          NaN
# 1  TV,Wifi,Air conditioning,Pool,Kitchen,Free par...         True
# 2  Hot water,TV,Air conditioning,Wifi,Kitchen,Dis...          NaN
# 3  TV,Wifi,Air conditioning,Kitchen,Free parking ...          NaN
# 4  Hair dryer,Shampoo,Hot water,Shower gel,Washer...          NaN
#
#   professional_management  min_nights cancellation_policy currency  \
# 0                   False         2.0            Moderate      GHS
# 1                   False         4.0            Moderate      GHS
# 2                   False         5.0            Moderate      GHS
# 3                   False         2.0            Moderate      GHS
# 4                   False         3.0            Moderate      GHS
#
#    cleaning_fee  extra_guest_fee  num_reviews  rating_overall  \
# 0           0.0              0.0         71.0            4.87
# 1          50.0              0.0         55.0            4.60
# 2          20.0             10.0         21.0            4.90
# 3          10.0             20.0         59.0            4.92
# 4          25.0             18.0        107.0            4.83
#
#    rating_accuracy  rating_checkin  rating_cleanliness  rating_communication  \
# 0              4.8             4.8                 4.9                   4.9
# 1              4.8             4.7                 4.5                   4.6
# 2              5.0             5.0                 4.8                   5.0
# 3              4.9             5.0                 4.8                   5.0
# 4              4.9             4.9                 4.9                   4.9
#
#    rating_location  rating_value  ttm_revenue  ttm_revenue_native  \
# 0              4.9           4.8         6948               87855
# 1              4.9           4.6         6428               73122
# 2              5.0           4.9         2533               26171
# 3              4.8           4.9         1719               17611
# 4              4.6           4.8         1423               18280
#
#    ttm_avg_rate  ttm_avg_rate_native  ttm_occupancy  ttm_adjusted_occupancy  \
# 0          41.9                498.8          0.452                   0.630
# 1          67.7                792.1          0.238                   0.282
# 2          53.3                633.1          0.126                   0.157
# 3          66.9                799.7          0.071                   0.093
# 4          47.5                561.5          0.082                   0.000
#
#    ttm_revpar  ttm_revpar_native  ttm_adjusted_revpar  \
# 0        19.0              240.7                 26.5
# 1        16.1              184.9                 19.0
# 2         6.8               70.6                  8.5
# 3         4.7               47.7                  6.1
# 4         3.8               48.7                  0.0
#
#    ttm_adjusted_revpar_native  ttm_reserved_days  ttm_blocked_days  \
# 0                       335.3                165               103
# 1                       218.4                 87                56
# 2                        87.9                 46                72
# 3                        62.2                 26                85
# 4                         0.0                 30                 0
#
#    ttm_available_days  ttm_total_days  l90d_revenue  l90d_revenue_native  \
# 0                 200             365          1753                17971
# 1                 278             365          1391                14249
# 2                 319             365           641                 6564
# 3                 339             365           971                 9948
# 4                 335             365           668                 6842
#
#    l90d_avg_rate  l90d_avg_rate_native  l90d_occupancy  \
# 0           39.0                 400.2           0.500
# 1           73.3                 750.4           0.189
# 2           48.9                 501.0           0.144
# 3           63.8                 653.1           0.167
# 4           45.3                 464.2           0.156
#
#    l90d_adjusted_occupancy  l90d_revpar  l90d_revpar_native  \
# 0                    0.763         19.5               199.7
# 1                    0.000         14.3               146.9
# 2                    0.271          6.9                70.7
# 3                    0.000         10.7               109.4
# 4                    0.000          7.1                73.2
#
#    l90d_adjusted_revpar  l90d_adjusted_revpar_native  l90d_reserved_days  \
# 0                  29.7                        304.6                  45
# 1                   0.0                          0.0                  17
# 2                  12.9                        132.5                  13
# 3                   0.0                          0.0                  15
# 4                   0.0                          0.0                  14
#
#    l90d_blocked_days  l90d_available_days  l90d_total_days geographic_zone  \
# 0                 31                   45             90.0          Africa
# 1                  0                   73             90.0          Africa
# 2                 42                   77             90.0          Africa
# 3                  0                   75             90.0          Africa
# 4                  0                   76             90.0          Africa
#
#    distance_from_city_center  city_population
# 0                   1.924028          1963264
# 1                   3.829708            44000
# 2                   0.423014            44000
# 3                   0.877089            44000
# 4                   5.023008           101207

# %%
print('DataFrame info:')
print('-' * 80)
df.info()

print('\nBasic checks:')
print('-' * 80)
print(f'Duplicated rows: {df.duplicated().sum():,}')
print(f'Total missing cells: {df.isna().sum().sum():,}')
print(f'Rows with at least one missing value: {df.isna().any(axis=1).sum():,}')

missing_pct_by_row = (df.isna().mean(axis=1) * 100)
print(f'Median missing % per row: {missing_pct_by_row.median():.2f}%')
print(f'95th percentile missing % per row: {missing_pct_by_row.quantile(0.95):.2f}%')
# Out:
# DataFrame info:
# --------------------------------------------------------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 47813 entries, 0 to 47812
# Data columns (total 65 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   listing_id                   47812 non-null  float64
#  1   listing_name                 47810 non-null  str
#  2   listing_type                 47813 non-null  str
#  3   room_type                    47813 non-null  str
#  4   cover_photo_url              47587 non-null  str
#  5   photos_count                 47587 non-null  float64
#  6   host_id                      47813 non-null  int64
#  7   host_name                    47435 non-null  str
#  8   cohost_ids                   11031 non-null  str
#  9   cohost_names                 11031 non-null  str
#  10  superhost                    47813 non-null  bool
#  11  latitude                     47813 non-null  float64
#  12  longitude                    47813 non-null  float64
#  13  guests                       41204 non-null  float64
#  14  bedrooms                     38884 non-null  float64
#  15  beds                         47332 non-null  float64
#  16  baths                        47777 non-null  float64
#  17  registration                 47672 non-null  object
#  18  amenities                    47804 non-null  str
#  19  instant_book                 6468 non-null   object
#  20  professional_management      43946 non-null  object
#  21  min_nights                   46221 non-null  float64
#  22  cancellation_policy          47779 non-null  str
#  23  currency                     47813 non-null  str
#  24  cleaning_fee                 44658 non-null  float64
#  25  extra_guest_fee              43596 non-null  float64
#  26  num_reviews                  47760 non-null  float64
#  27  rating_overall               46385 non-null  float64
#  28  rating_accuracy              46385 non-null  float64
#  29  rating_checkin               46385 non-null  float64
#  30  rating_cleanliness           46385 non-null  float64
#  31  rating_communication         46385 non-null  float64
#  32  rating_location              46385 non-null  float64
#  33  rating_value                 46385 non-null  float64
#  34  ttm_revenue                  47813 non-null  int64
#  35  ttm_revenue_native           47813 non-null  int64
#  36  ttm_avg_rate                 47813 non-null  float64
#  37  ttm_avg_rate_native          47813 non-null  float64
#  38  ttm_occupancy                47813 non-null  float64
#  39  ttm_adjusted_occupancy       47813 non-null  float64
#  40  ttm_revpar                   47813 non-null  float64
#  41  ttm_revpar_native            47813 non-null  float64
#  42  ttm_adjusted_revpar          47813 non-null  float64
#  43  ttm_adjusted_revpar_native   47813 non-null  float64
#  44  ttm_reserved_days            47813 non-null  int64
#  45  ttm_blocked_days             47813 non-null  int64
#  46  ttm_available_days           47813 non-null  int64
#  47  ttm_total_days               47813 non-null  int64
#  48  l90d_revenue                 47813 non-null  int64
#  49  l90d_revenue_native          47813 non-null  int64
#  50  l90d_avg_rate                47813 non-null  float64
#  51  l90d_avg_rate_native         47813 non-null  float64
#  52  l90d_occupancy               47813 non-null  float64
#  53  l90d_adjusted_occupancy      47813 non-null  float64
#  54  l90d_revpar                  47813 non-null  float64
#  55  l90d_revpar_native           47813 non-null  float64
#  56  l90d_adjusted_revpar         47813 non-null  float64
#  57  l90d_adjusted_revpar_native  47813 non-null  float64
#  58  l90d_reserved_days           47813 non-null  int64
#  59  l90d_blocked_days            47813 non-null  int64
#  60  l90d_available_days          47813 non-null  int64
#  61  l90d_total_days              47812 non-null  float64
#  62  geographic_zone              47813 non-null  str
#  63  distance_from_city_center    47813 non-null  float64
#  64  city_population              47813 non-null  int64
# dtypes: bool(1), float64(37), int64(13), object(3), str(11)
# memory usage: 23.4+ MB
#
# Basic checks:
# --------------------------------------------------------------------------------
# Duplicated rows: 847
# Total missing cells: 154,863
# Rows with at least one missing value: 47,233
# Median missing % per row: 4.62%
# 95th percentile missing % per row: 9.23%

# %% [markdown]
# ## Missingness and Data Quality Checks

# %%
missing_summary = (
    df.isna()
    .sum()
    .rename('missing_count')
    .to_frame()
    .assign(missing_pct=lambda x: (x['missing_count'] / len(df) * 100).round(2))
    .sort_values('missing_count', ascending=False)
)

missing_summary.head(20)

plt.figure(figsize=(12, 6))
plot_missing = missing_summary[missing_summary['missing_count'] > 0].head(20)
if not plot_missing.empty:
    sns.barplot(
        data=plot_missing.reset_index(),
        x='missing_pct',
        y='index',
        color='steelblue'
    )
    plt.title('Top 20 Columns by Missing Percentage')
    plt.xlabel('Missing (%)')
    plt.ylabel('Column')
else:
    plt.text(0.5, 0.5, 'No missing values found', ha='center', va='center')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
df_plot = df.copy()
converted_to_numeric = []
converted_to_bool = []

for col in df_plot.columns:
    series = df_plot[col]
    if series.dtype != 'object':
        continue

    non_null = series.dropna().astype(str).str.strip()
    if non_null.empty:
        continue

    upper_values = set(non_null.str.upper().unique())
    if upper_values.issubset({'TRUE', 'FALSE'}):
        mapped = series.astype(str).str.strip().str.upper().map({'TRUE': True, 'FALSE': False})
        mapped[series.isna()] = np.nan
        df_plot[col] = mapped
        converted_to_bool.append(col)
        continue

    numeric_candidate = pd.to_numeric(
        series.astype(str).str.replace(',', '', regex=False).str.strip(),
        errors='coerce'
    )
    if numeric_candidate.notna().mean() >= 0.85:
        df_plot[col] = numeric_candidate
        converted_to_numeric.append(col)

print(f'Converted to numeric for EDA: {len(converted_to_numeric)} columns')
print(converted_to_numeric[:20])
print(f'Converted to boolean for EDA: {len(converted_to_bool)} columns')
print(converted_to_bool)

df_plot.select_dtypes(include='number').describe().T.head(15)
# Out:
# Converted to numeric for EDA: 0 columns
# []
# Converted to boolean for EDA: 3 columns
# ['registration', 'instant_book', 'professional_management']
#                    count          mean           std       min           25%  \
# listing_id       47812.0  7.040707e+16  2.463897e+17    6.0000  3.298538e+06
# photos_count     47587.0  2.992904e+01  2.124905e+01    0.0000  1.600000e+01
# host_id          47813.0  9.507820e+07  1.348580e+08   29.0000  7.101186e+06
# latitude         47813.0  2.146413e+01  2.672454e+01  -45.0767  6.218400e+00
# longitude        47813.0 -5.628457e-01  7.351114e+01 -157.8614 -7.124940e+01
# guests           41204.0  4.313198e+00  2.674183e+00    1.0000  2.000000e+00
# bedrooms         38884.0  1.897979e+00  1.254535e+00    0.0000  1.000000e+00
# beds             47332.0  2.484324e+00  2.049747e+00    0.0000  1.000000e+00
# baths            47777.0  1.341702e+00  1.135360e+00    0.0000  1.000000e+00
# min_nights       46221.0  6.953917e+00  3.542510e+01    1.0000  1.000000e+00
# cleaning_fee     44658.0  4.050116e+01  8.003772e+01    0.0000  0.000000e+00
# extra_guest_fee  43596.0  2.054271e+00  8.736399e+00    0.0000  0.000000e+00
# num_reviews      47760.0  1.316994e+02  1.601174e+02    0.0000  2.700000e+01
# rating_overall   46385.0  4.775643e+00  1.956826e-01    2.3300  4.690000e+00
# rating_accuracy  46385.0  4.812918e+00  1.826324e-01    2.3000  4.800000e+00
#
#                           50%           75%           max
# listing_id       1.405069e+07  2.933034e+07  1.340000e+18
# photos_count     2.500000e+01  3.700000e+01  4.930000e+02
# host_id          3.386090e+07  1.263438e+08  7.374132e+08
# latitude         3.041030e+01  4.104960e+01  5.940720e+01
# longitude        1.030980e+01  3.262240e+01  1.748477e+02
# guests           4.000000e+00  6.000000e+00  1.600000e+01
# bedrooms         2.000000e+00  2.000000e+00  4.100000e+01
# beds             2.000000e+00  3.000000e+00  5.000000e+01
# baths            1.000000e+00  2.000000e+00  3.800000e+01
# min_nights       2.000000e+00  3.000000e+00  9.990000e+02
# cleaning_fee     1.700000e+01  5.000000e+01  7.770000e+03
# extra_guest_fee  0.000000e+00  0.000000e+00  5.530000e+02
# num_reviews      7.300000e+01  1.770000e+02  3.784000e+03
# rating_overall   4.820000e+00  4.910000e+00  5.000000e+00
# rating_accuracy  4.900000e+00  4.900000e+00  5.000000e+00

# %%
categorical_focus = [
    col for col in ['city', 'country', 'geographic_zone', 'room_type', 'listing_type', 'cancellation_policy']
    if col in df_plot.columns
]

if categorical_focus:
    n_cols = 2
    n_rows = int(np.ceil(len(categorical_focus) / n_cols))
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, 4.5 * n_rows))
    axes = np.atleast_1d(axes).flatten()

    for ax, col in zip(axes, categorical_focus):
        top_counts = df_plot[col].astype(str).value_counts(dropna=False).head(12)
        sns.barplot(
            x=top_counts.values,
            y=top_counts.index,
            ax=ax,
            color='seagreen'
        )
        ax.set_title(f'Top Categories: {col}')
        ax.set_xlabel('Count')
        ax.set_ylabel('')

    for ax in axes[len(categorical_focus):]:
        ax.axis('off')

    plt.tight_layout()
    plt.show()

for col in categorical_focus:
    print(f'\nTop values for {col}:')
    display(df_plot[col].value_counts(dropna=False).head(10).to_frame('count'))
# Out:
# Top values for geographic_zone:
#                   count
# geographic_zone
# Northern America   8943
# Europe             8911
# Asia Pacific       8193
# Latin America      8016
# Africa             7215
# Middle East        6535
# Top values for room_type:
#               count
# room_type
# entire_home   38426
# private_room   8781
# hotel_room      414
# shared_room     192
# Top values for listing_type:
#                              count
# listing_type
# Entire rental unit           19773
# Entire condo                  5201
# Entire home                   4950
# Private room in home          2664
# Private room in rental unit   2192
# Entire serviced apartment     1606
# Entire villa                  1410
# Entire loft                   1075
# Entire guest suite            1068
# Entire guesthouse              801
# Top values for cancellation_policy:
#                       count
# cancellation_policy
# Firm                  15115
# Moderate              13652
# Flexible               9994
# Strict                 7147
# Limited                 872
# Super Strict 30 Days    345
# Super Strict 60 Days    260
# Refundable              211
# Non-refundable          180
# NaN                      34

# %%
numeric_cols = df_plot.select_dtypes(include='number').columns.tolist()

priority_numeric = [
    'ttm_revenue', 'ttm_avg_rate', 'ttm_occupancy', 'ttm_revpar',
    'l90d_revenue', 'l90d_avg_rate', 'l90d_occupancy', 'l90d_revpar',
    'distance_from_city_center', 'rating_overall', 'num_reviews',
    'guests', 'bedrooms', 'beds', 'baths'
]

hist_cols = [c for c in priority_numeric if c in numeric_cols]
if len(hist_cols) < 12:
    extras = [c for c in numeric_cols if c not in hist_cols]
    hist_cols.extend(extras[: 12 - len(hist_cols)])

hist_cols = hist_cols[:12]
n_cols = 3
n_rows = int(np.ceil(len(hist_cols) / n_cols)) if hist_cols else 1
fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, 4.5 * n_rows))
axes = np.atleast_1d(axes).flatten()

for ax, col in zip(axes, hist_cols):
    sns.histplot(df_plot[col].dropna(), bins=40, kde=True, ax=ax, color='teal')
    ax.set_title(f'Histogram: {col}')

for ax in axes[len(hist_cols):]:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation and Relationship Analysis

# %%
corr_priority = [
    'ttm_revenue', 'ttm_avg_rate', 'ttm_occupancy', 'ttm_adjusted_occupancy',
    'ttm_revpar', 'ttm_adjusted_revpar', 'l90d_revenue', 'l90d_avg_rate',
    'l90d_occupancy', 'l90d_adjusted_occupancy', 'l90d_revpar',
    'distance_from_city_center', 'rating_overall', 'num_reviews',
    'guests', 'bedrooms', 'beds', 'baths'
]

corr_cols = [c for c in corr_priority if c in df_plot.columns and c in numeric_cols]

if len(corr_cols) >= 2:
    corr_matrix = df_plot[corr_cols].corr(numeric_only=True)

    plt.figure(figsize=(14, 10))
    sns.heatmap(
        corr_matrix,
        cmap='RdBu_r',
        center=0,
        vmin=-1,
        vmax=1,
        annot=False,
        square=True,
        cbar_kws={'shrink': 0.8}
    )
    plt.title('Correlation Heatmap (Selected Numeric Features)')
    plt.tight_layout()
    plt.show()

    corr_pairs = (
        corr_matrix.where(~np.eye(corr_matrix.shape[0], dtype=bool))
        .stack()
        .rename('correlation')
        .reset_index()
        .rename(columns={'level_0': 'feature_1', 'level_1': 'feature_2'})
    )
    corr_pairs['abs_corr'] = corr_pairs['correlation'].abs()
    top_corr = corr_pairs.sort_values('abs_corr', ascending=False).drop_duplicates(subset=['abs_corr']).head(12)

    print('Top absolute correlations (excluding self-correlation):')
    display(top_corr[['feature_1', 'feature_2', 'correlation']])
else:
    print('Not enough numeric columns available for correlation analysis.')
# Out:
# Top absolute correlations (excluding self-correlation):
#           feature_1      feature_2  correlation
# 4       ttm_revenue     ttm_revpar     0.998007
# 118    l90d_revenue    l90d_revpar     0.997755
# 25     ttm_avg_rate  l90d_avg_rate     0.954993
# 6       ttm_revenue   l90d_revenue     0.856794
# 112    l90d_revenue     ttm_revpar     0.852761
# 180     l90d_revpar    ttm_revenue     0.851059
# 82       ttm_revpar    l90d_revpar     0.850774
# 268          guests           beds     0.814326
# 267          guests       bedrooms     0.813088
# 303            beds       bedrooms     0.794455
# 146  l90d_occupancy  ttm_occupancy     0.782165
# 287        bedrooms          baths     0.732299

# %%
scatter_pairs = [
    ('ttm_avg_rate', 'ttm_occupancy'),
    ('distance_from_city_center', 'ttm_revenue'),
    ('l90d_avg_rate', 'l90d_occupancy'),
    ('num_reviews', 'rating_overall'),
]

available_pairs = [
    (x, y) for x, y in scatter_pairs
    if x in df_plot.columns and y in df_plot.columns
]

plot_df = df_plot.copy()
for x, y in available_pairs:
    plot_df = plot_df[plot_df[x].notna() & plot_df[y].notna()]

if len(plot_df) > 8000:
    plot_df = plot_df.sample(8000, random_state=RANDOM_STATE)

if available_pairs:
    n_cols = 2
    n_rows = int(np.ceil(len(available_pairs) / n_cols))
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, 5 * n_rows))
    axes = np.atleast_1d(axes).flatten()

    hue_col = 'geographic_zone' if 'geographic_zone' in plot_df.columns else None

    for ax, (x_col, y_col) in zip(axes, available_pairs):
        sns.scatterplot(
            data=plot_df,
            x=x_col,
            y=y_col,
            hue=hue_col,
            alpha=0.35,
            s=25,
            ax=ax,
            legend=False
        )
        ax.set_title(f'Scatter: {y_col} vs {x_col}')

    for ax in axes[len(available_pairs):]:
        ax.axis('off')

    plt.tight_layout()
    plt.show()
else:
    print('No predefined scatterplot pairs found in current data.')

# %%
key_metrics = [
    c for c in ['ttm_revenue', 'ttm_avg_rate', 'ttm_occupancy', 'l90d_revenue', 'l90d_avg_rate', 'l90d_occupancy']
    if c in df_plot.columns
]

if key_metrics:
    all_key_missing = df_plot[key_metrics].isna().all(axis=1)
    print(f'Rows with all key performance metrics missing: {all_key_missing.sum():,} / {len(df_plot):,}')

outlier_cols = [c for c in ['ttm_revenue', 'l90d_revenue', 'ttm_avg_rate', 'l90d_avg_rate', 'distance_from_city_center'] if c in numeric_cols]
if outlier_cols:
    n_cols = 3
    n_rows = int(np.ceil(len(outlier_cols) / n_cols))
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, 4.5 * n_rows))
    axes = np.atleast_1d(axes).flatten()

    for ax, col in zip(axes, outlier_cols):
        sns.boxplot(x=df_plot[col], ax=ax, color='lightcoral')
        ax.set_title(f'Boxplot: {col}')

    for ax in axes[len(outlier_cols):]:
        ax.axis('off')

    plt.tight_layout()
    plt.show()
# Out:
# Rows with all key performance metrics missing: 0 / 47,813
